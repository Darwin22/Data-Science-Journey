# %%
#importing pandas, matplotlib and numpy packages
import pandas as pd
import matplotlib as plt
import numpy as np
# %matplotlib inline

# %%
#reading in a csv file has become a lot easier since the first project. Now i can use pandas to read it and dont have to write four lines of code
recent_grads = pd.read_csv("recent-grads.csv")

# %%
#location of the first row
recent_grads.iloc[:1]
# Out:
#    Rank  Major_code                  Major   Total     Men  Women  \
# 0     1        2419  PETROLEUM ENGINEERING  2339.0  2057.0  282.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
#
# [1 rows x 21 columns]

# %%
#displaying the first two rows to see what data I am dealing with
recent_grads.head(2)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
# 1    Engineering    0.101852            7       640      ...              170
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
# 1           350               257             50
#
# [2 rows x 21 columns]

# %%
#last four rows of the dataframa
recent_grads.tail(4)
# Out:
#      Rank  Major_code                   Major   Total    Men   Women  \
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0  522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0  568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0  931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0  134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 169      ...              572                  1211         148
# 170      ...              648                  1293         368
# 171      ...              965                  2738         214
# 172      ...              237                   410          87
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 169           0.065112   25000  24000  34000          1488               615
# 170           0.149048   25000  25000  40000           986               870
# 171           0.053621   23400  19200  26000          2403              1245
# 172           0.104946   22000  20000  22000           288               338
#
#      Low_wage_jobs
# 169             82
# 170            622
# 171            308
# 172            192
#
# [4 rows x 21 columns]

# %%
#.describe tells me the stats for the entire dataset. This is extremely helpful when I am trying to find differences between two or more columns,for example men and women.
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# std      0.231205   618.361022   50675.002241   42869.655092   14648.179473
# min      0.000000     2.000000       0.000000     111.000000       0.000000
# 25%      0.336026    39.000000    3608.000000    3154.000000    1030.000000
# 50%      0.534024   130.000000   11797.000000   10048.000000    3299.000000
# 75%      0.703299   338.000000   31433.000000   25147.000000    9948.000000
# max      0.968954  4212.000000  307933.000000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            173.000000    173.000000         173.000000     173.000000
# mean           19694.427746   2416.329480           0.068191   40151.445087
# std            33160.941514   4112.803148           0.030331   11470.181802
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2453.000000    304.000000           0.050306   33000.000000
# 50%             7413.000000    893.000000           0.067961   36000.000000
# 75%            16891.000000   2393.000000           0.087557   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    173.000000     173.000000     173.000000        173.000000
# mean   29501.445087   51494.219653   12322.635838      13284.497110
# std     9166.005235   14906.279740   21299.868863      23789.655363
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   42000.000000    1675.000000       1591.000000
# 50%    27000.000000   47000.000000    4390.000000       4595.000000
# 75%    33000.000000   60000.000000   14444.000000      11783.000000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     173.000000
# mean     3859.017341
# std      6944.998579
# min         0.000000
# 25%       340.000000
# 50%      1231.000000
# 75%      3466.000000
# max     48207.000000

# %%
raw_data_count = 173
recent_grads = recent_grads.dropna()

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# std      0.231205   619.680419   50777.42865   42957.122320   14679.038729
# min      0.000000     2.000000       0.00000     111.000000       0.000000
# 25%      0.336026    42.000000    3734.75000    3181.000000    1013.750000
# 50%      0.534024   131.000000   12031.50000   10073.500000    3332.500000
# 75%      0.703299   339.000000   31701.25000   25447.250000    9981.000000
# max      0.968954  4212.000000  307933.00000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            172.000000    172.000000         172.000000     172.000000
# mean           19798.843023   2428.412791           0.068024   40076.744186
# std            33229.227514   4121.730452           0.030340   11461.388773
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2474.750000    299.500000           0.050261   33000.000000
# 50%             7436.500000    905.000000           0.067544   36000.000000
# 75%            17674.750000   2397.000000           0.087247   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    172.000000     172.000000     172.000000        172.000000
# mean   29486.918605   51386.627907   12387.401163      13354.325581
# std     9190.769927   14882.278650   21344.967522      23841.326605
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   41750.000000    1744.750000       1594.000000
# 50%    27000.000000   47000.000000    4467.500000       4603.500000
# 75%    33250.000000   58500.000000   14595.750000      11791.750000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     172.000000
# mean     3878.633721
# std      6960.467621
# min         0.000000
# 25%       336.750000
# 50%      1238.500000
# 75%      3496.000000
# max     48207.000000

# %%
cleaned_data_count = 172

# %%
#making sure that there was only one row with missing data
raw_data_count - cleaned_data_count
# Out:
# 1

# %%
#displaying what columns there are in the dataset
recent_grads.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
#yay! I finally made a scatterplot with the sample size on the x-axis and Median on the y-axis.
Samplesize_and_median = recent_grads.plot(x="Sample_size",y="Median",kind = "scatter")
Samplesize_and_median.set_title("Samplesize and Median")

# %%
#Some more scatterplots! This time it is to see the correlation between the sample size and the unemployment rate
Samplesize_and_unemploymentrate = recent_grads.plot(x="Sample_size",y="Unemployment_rate",kind = "scatter")
Samplesize_and_unemploymentrate.set_title("Samplesize and Unemployment Rate")

# %%
Fulltime_and_median = recent_grads.plot(x="Full_time",y="Median",kind = "scatter")
Fulltime_and_median.set_title("Full-Time and Median")

# %%
#Scatterplot to seee if women have higher percentages of unemployment or not
Sharewomen_and_unemploymentrate = recent_grads.plot(x="ShareWomen",y="Unemployment_rate",kind = "scatter")
Sharewomen_and_unemploymentrate.set_title("Share-women and Unemployment Rate")

# %%
men_and_median = recent_grads.plot(x="Men",y="Median",kind = "scatter")
men_and_median.set_title("Men and Median")

# %%
women_and_median = recent_grads.plot(x="Women",y="Median",kind = "scatter")
women_and_median.set_title("Women and Median")

# %% [markdown]
# I am so glad to be able to make scatterplots. This would probably be my first big accomplishment after finishing learning python in under 2 months.

# %%
#histograms created for multiple columns. This was to see the freqency of the sample sizes.
recent_grads['Sample_size'].plot(kind='hist')

# %%
recent_grads['Median'].plot(kind='hist')

# %%
recent_grads['Employed'].plot(kind='hist')

# %%
recent_grads['Full_time'].plot(kind='hist')

# %%
recent_grads['ShareWomen'].plot(kind='hist')

# %%
recent_grads['Unemployment_rate'].plot(kind='hist')

# %%
recent_grads['Men'].plot(kind='hist')

# %%
recent_grads['Women'].plot(kind='hist')

# %%
#importing scatter-matrix so I can compare scatterplots and histograms
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[["Sample_size","Men"]],
figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111ad7c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111b51fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111c5e438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111caea20>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Men","Unemployment_rate"]],
figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111d6d3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112206c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112277160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1122ca668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112335978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1123359b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1123f9518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112454320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1124bd470>]], dtype=object)

# %% [markdown]
# We can see from this scatterplot that the majority of men are employed and that there are a few outliers who are unemployed.

# %%
#Percentages of women by top 10 and bottom 10 majors
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %% [markdown]
# We can now compare the percentages of women from the 10 highest and the 10 lowest paying majors in the above bar charts

# %%
#unemployment rate for top 10 and bottom 10 majors
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %% [markdown]
# the above two charts can be used to compare the unemployment rate based on majors

# %%
recent_grads.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')
